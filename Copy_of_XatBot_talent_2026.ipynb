# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanrodriguez-rgb/talentosa/blob/main/Copy_of_XatBot_talent_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. INSTAL·LACIÓ
# !pip install -q -U google-genai flask-cors pyngrok beautifulsoup4 requests
# !pip install requests==2.32.4

import json, requests, time, re
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from flask import Flask, request, jsonify
from flask_cors import CORS
from pyngrok import ngrok
from google.colab import userdata
from google import genai

# --- CONFIGURACIÓ DE SEGURETAT ---
try:
    client = genai.Client(api_key=userdata.get('GOOGLE_API_KEY'))
    ngrok.set_auth_token(userdata.get('token_ngrok'))
    print("✅ API i ngrok connectats.")
except Exception as e:
    print(f"❌ ERROR SECRETS: {e}")

app = Flask(__name__)
CORS(app)

# --- EXTRACTOR TOTAL (Amb els noms de les pàgines en directe) ---
URL_BASE = "https://irodriguez.inscastellbisbal.net/"
dades_ivan = []

def executar_extractor_total():
    global dades_ivan
    urls_visitades = set()
    urls_per_visitar = [URL_BASE]
    domini = urlparse(URL_BASE).netloc

    print(f"🚀 Iniciant extracció massiva de {URL_BASE}...")

    # Límit pujat a 200 per agafar totes les teves entrades
    while urls_per_visitar and len(urls_visitades) < 257:
        url = urls_per_visitar.pop(0)

        if url in urls_visitades or any(x in url.lower() for x in ['.jpg', '.png', '.pdf', 'wp-admin', 'wp-json']):
            continue

        try:
            res = requests.get(url, timeout=10)
            if res.status_code != 200: continue

            soup = BeautifulSoup(res.text, 'html.parser')
            urls_visitades.add(url)

            titol = soup.title.string.strip() if soup.title else "Pàgina sense títol"
            blocs_text = [t.get_text(strip=True) for t in soup.find_all(['p', 'h1', 'h2', 'h3', 'li'])]
            contingut_net = " ".join([t for t in blocs_text if len(t) > 10])

            if len(contingut_net) > 50:
                # Guardem la info
                dades_ivan.append({"url": url, "titol": titol, "contingut": contingut_net})

                # AQUESTA ÉS LA LÍNIA QUE VOLIES: Mostra el títol exacte de cada pàgina extreta
                print(f"✅ [{len(urls_visitades)}] Guardat: {titol[:60]}")

            # Buscar més enllaços
            for a in soup.find_all('a', href=True):
                enllac = urljoin(URL_BASE, a['href'])
                if urlparse(enllac).netloc == domini and enllac not in urls_visitades:
                    urls_per_visitar.append(enllac)

        except Exception:
            continue

    with open('dades_ivan_total.json', 'w', encoding='utf-8') as f:
        json.dump(dades_ivan, f, ensure_ascii=False, indent=4)
    print(f"\n📁 BBDD FINALITZADA: {len(dades_ivan)} pàgines i entrades guardades amb èxit!")

# --- CERCADOR INTEL·LIGENT ---
def trobar_pagines_rellevants(pregunta, maxim=3):
    paraules = re.findall(r'\w+', pregunta.lower())
    resultats = []

    for pagina in dades_ivan:
        text_pagina = (pagina['titol'] + " " + pagina['contingut']).lower()
        puntuacio = sum(1 for p in paraules if len(p) > 3 and p in text_pagina)
        resultats.append((puntuacio, pagina))

    resultats.sort(key=lambda x: x[0], reverse=True)
    return [r[1] for r in resultats[:maxim]]

# --- LÒGICA IA ---
def demanar_a_ia(pregunta):
    pagines_filtrades = trobar_pagines_rellevants(pregunta, maxim=3)

    context = "Ets l'assistent del portafolis d'en Ivan Rodriguez. Respon de forma amable en català basant-te NOMÉS en aquesta informació real del seu web:\n\n"
    for d in pagines_filtrades:
        context += f"Títol: {d['titol']}\nInfo: {d['contingut'][:600]}...\n---\n"

    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=f"{context}\n\nPregunta: {pregunta}"
    )
    return response.text

# --- RUTES I SERVIDOR ---
@app.route('/ask', methods=['POST'])
def ask():
    try:
        msg = request.json.get("message")
        print(f"📩 Usuari pregunta: {msg}")
        resposta = demanar_a_ia(msg)
        return jsonify({"reply": resposta})
    except Exception as e:
        print(f"❌ Error BackEnd: {e}")
        return jsonify({"reply": f"Error: {str(e)}"}), 500

if __name__ == '__main__':
    # 1. Fem l'extracció de tota la web
    executar_extractor_total()

    # 2. Encenem el servidor
    # !pkill ngrok
    time.sleep(2)
    public_url = ngrok.connect(5000).public_url
    print(f"\n🌍 URL PER AL TEU JAVASCRIPT:\n{public_url}/ask\n")
    app.run(port=5000)
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.53.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# google-adk 1.29.0 requires google-genai<2.0.0,>=1.64.0, but you have google-genai 2.8.0 which is incompatible.
# Collecting requests==2.32.4
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.4) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.4) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.4) (2026.5.20)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Installing collected packages: requests
#   Attempting uninstall: requests
#     Found existing installation: requests 2.34.2
#     Uninstalling requests-2.34.2:
#       Successfully uninstalled requests-2.34.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.53.0 which is incompatible.
# google-adk 1.29.0 requires google-genai<2.0.0,>=1.64.0, but you have google-genai 2.8.0 which is incompatible.
# Successfully installed requests-2.32.4
# ✅ API i ngrok connectats.
# 🚀 Iniciant extracció massiva de https://irodriguez.inscastellbisbal.net/...
# ✅ [1] Guardat: Ivan Rodriguez Jimenez - Hola, em dic Iván, tinc 16 anys i a
# ✅ [2] Guardat: Ivan Rodriguez Jimenez - Hola, em dic Iván, tinc 16 anys i a
# ✅ [3] Guardat: Política de privadesa - Ivan Rodriguez Jimenez
# ✅ [4] Guardat: Repte 1.1 - Ivan Rodriguez Jimenez
# ✅ [5] Guardat: Repte 1.2 - Ivan Rodriguez Jimenez
# ✅ [6] Guardat: Repte 1.3 - Ivan Rodriguez Jimenez
# ✅ [7] Guardat: Repte 1.4 - Ivan Rodriguez Jimenez
# ✅ [8] Guardat: Apuntes clase - Ivan Rodriguez Jimenez
# ✅ [9] Guardat: 8 navegadors:(SO,Motor de rendiment,Velocitat,Consum de recu
# ✅ [10] Guardat: COM SINCRONITZAR DROPBOX AMB DRIVE - Ivan Rodriguez Jimenez
# ✅ [11] Guardat: reconeixements de components de pc - Ivan Rodriguez Jimenez
# ✅ [12] Guardat: SEO I SEM - Ivan Rodriguez Jimenez
# ✅ [13] Guardat: Contacta’m - Ivan Rodriguez Jimenez
# ✅ [14] Guardat: SMX1 - Ivan Rodriguez Jimenez
# ✅ [15] Guardat: 1️ Correu corporatiu del centre - Ivan Rodriguez Jimenez
# ✅ [16] Guardat: Configuració de la safata d'entrada amb etiquetes - Ivan Rod
# ✅ [17] Guardat: Configuracion de safata de d'entrada amb etiquetes - Ivan Ro
# ✅ [18] Guardat: Configuracion de signatura - Ivan Rodriguez Jimenez
# ✅ [19] Guardat: Creació de regles de filtrat de correu - Ivan Rodriguez Jime
# ✅ [20] Guardat: Sincronitzacio en el mobil del correu i xat - Ivan Rodriguez
# ✅ [21] Guardat: Agenda electronica - Ivan Rodriguez Jimenez
# ✅ [22] Guardat: Compartir el calendari personal amb el corporatiu - Ivan Rod
# ✅ [23] Guardat: Configuració de l'horari acadèmic en el correu corporatiu -
# ✅ [24] Guardat: Configuració de l'horari personal en el compte personal crea
# ✅ [25] Guardat: Sincronització del calendari amb el mòbil - Ivan Rodriguez J
# ✅ [26] Guardat: Correu profesional - Ivan Rodriguez Jimenez
# ✅ [27] Guardat: Configuració d'una resposta automàtica que informi del corre
# ✅ [28] Guardat: Configuració d'una signatura - Ivan Rodriguez Jimenez
# ✅ [29] Guardat: Configuració de redirecció al correu corporatiu - Ivan Rodri
# ✅ [30] Guardat: Correo professional - Ivan Rodriguez Jimenez
# ✅ [31] Guardat: Poder enviar correus en nom d'aquest compte des del correu c
# ✅ [32] Guardat: Creació d'un correu per temes acadèmics i professionals iden
# ✅ [33] Guardat: Espai de treball a casa - Ivan Rodriguez Jimenez
# ✅ [34] Guardat: Accés a totes les plataformes web - Ivan Rodriguez Jimenez
# ✅ [35] Guardat: Configuració del gestor de bookmarks al navegador profession
# ✅ [36] Guardat: Configuració del gestor de contrasenyes al navegador profess
# ✅ [37] Guardat: Creació d’un compte al sistema operatiu per temes profession
# ✅ [38] Guardat: Instal·lació d’un navegador per temes professionals i acadèm
# ✅ [39] Guardat: Instal·lació de Filezilla - Ivan Rodriguez Jimenez
# ✅ [40] Guardat: Instal·lació de Packet Tracer - Ivan Rodriguez Jimenez
# ✅ [41] Guardat: Instal·lació de VirtualBox i vagrant - Ivan Rodriguez Jimene
# ✅ [42] Guardat: Instal·lació de Visual Studio Code i Python - Ivan Rodriguez
# ✅ [43] Guardat: Instalació d’un programa per fer i editar captures de pantal
# ✅ [44] Guardat: Espai de treball al núvol - Ivan Rodriguez Jimenez
# ✅ [45] Guardat: Comparativa de gestors de fitxers al núvol - Ivan Rodriguez
# ✅ [46] Guardat: Copies de seguretat al núvol - Ivan Rodriguez Jimenez
# ✅ [47] Guardat: Diferència entre compartir recursos i unitats compartides -
# ✅ [48] Guardat: Estructura de directoris de treball a drive - Ivan Rodriguez
# ✅ [49] Guardat: Sincronització d’escriptori amb el núvol. - Ivan Rodriguez J
# ✅ [50] Guardat: Utilització de marcadors en documents de Drive - Ivan Rodrig
# ✅ [51] Guardat: Llibre d'estil - Ivan Rodriguez Jimenez
# ✅ [52] Guardat: Creació d'una imatge corporativa - Ivan Rodriguez Jimenez
# ✅ [53] Guardat: Elecció d'un tema - Ivan Rodriguez Jimenez
# ✅ [54] Guardat: Eleccion dels plugins a i implementor - Ivan Rodriguez Jimen
# ✅ [55] Guardat: Plantilla del disseny de les pàgines (text, imatges, ubicaci
# ✅ [56] Guardat: Tipus de lletres utilitzades - Ivan Rodriguez Jimenez
# ✅ [57] Guardat: Utilització d'una tonalitat de colors corporativa - Ivan Rod
# ✅ [58] Guardat: Plataformes Web - Ivan Rodriguez Jimenez
# ✅ [59] Guardat: Accés a Miro amb el compte corporatiu - Ivan Rodriguez Jimen
# ✅ [60] Guardat: Accés a Moodle amb el compte corporatiu - Ivan Rodriguez Jim
# ✅ [61] Guardat: Accés a Netacad amb el compte professional - Ivan Rodriguez
# ✅ [62] Guardat: Acces a totes les eines de Google amb el correu corporatiu -
# ✅ [63] Guardat: Utilitzacio d’un gestor de bookmarks integrat al navegador -
# ✅ [64] Guardat: Utilització d’un gestor de contrasenyes integrat al navegado
# ✅ [65] Guardat: Portfoli digital - Ivan Rodriguez Jimenez
# ✅ [66] Guardat: Accés administració Wordpress - Ivan Rodriguez Jimenez
# ✅ [67] Guardat: Compte major amb permisos totals del Wordpress - Ivan Rodrig
# ✅ [68] Guardat: Creació d’etiquetes per categoritzar les entrades - Ivan Rod
# ✅ [69] Guardat: Creació d’un menú per les entrades - Ivan Rodriguez Jimenez
# ✅ [70] Guardat: Fer el desplegament de WordPress - Ivan Rodriguez Jimenez
# ✅ [71] Guardat: Galetes i configuració de privadesa - Ivan Rodriguez Jimenez
# ✅ [72] Guardat: Securització del WordPress - Ivan Rodriguez Jimenez
# ✅ [73] Guardat: SEO i posicionament - Ivan Rodriguez Jimenez
# ✅ [74] Guardat: Internacionalització - Ivan Rodriguez Jimenez
# ✅ [75] Guardat: Cheat Sheet about Linux commands - Ivan Rodriguez Jimenez
# ✅ [76] Guardat: Infographics of Linux Operating Systems - Ivan Rodriguez Jim
# ✅ [77] Guardat: Moodle's guide (quizzes) - Ivan Rodriguez Jimenez
# ✅ [78] Guardat: Review your comprehension - Ivan Rodriguez Jimenez
# ✅ [79] Guardat: Prevenció de Riscos Laborals - Ivan Rodriguez Jimenez
# ✅ [80] Guardat: Elaboració d'un pla de protecció per l'aula - Ivan Rodriguez
# ✅ [81] Guardat: Identifica els perills i riscos dins de l'aula - Ivan Rodrig
# ✅ [82] Guardat: Informe de malalties professionals més comuns del teu sector
# ✅ [83] Guardat: Informe de propostes de millora per corregir els riscos de l
# ✅ [84] Guardat: Informe de riscos d'accidents en el teu lloc de treball - Iv
# ✅ [85] Guardat: Interpretació d'un pla de protecció de riscos - Ivan Rodrigu
# ✅ [86] Guardat: Llistat dels EPIs necessaris en el teu sector - Ivan Rodrigu
# ✅ [87] Guardat: Servidor de servidors - Ivan Rodriguez Jimenez
# ✅ [88] Guardat: Assamblament de components - Ivan Rodriguez Jimenez
# ✅ [89] Guardat: Cablejat elèctric - Ivan Rodriguez Jimenez
# ✅ [90] Guardat: Elecció de components - Ivan Rodriguez Jimenez
# ✅ [91] Guardat: Neteja i adequació dels components - Ivan Rodriguez Jimenez
# ✅ [92] Guardat: Servidor Moodle - Ivan Rodriguez Jimenez
# ✅ [93] Guardat: Caducitat de subscripcions - Ivan Rodriguez Jimenez
# ✅ [94] Guardat: Cohorts - Ivan Rodriguez Jimenez
# ✅ [95] Guardat: Creació de cursos - Ivan Rodriguez Jimenez
# ✅ [96] Guardat: Creació de proves lingüístiques - Ivan Rodriguez Jimenez
# ✅ [97] Guardat: Gestió usuaris - Ivan Rodriguez Jimenez
# ✅ [98] Guardat: Instal·lació de Moodle a la màquina amb Debian - Ivan Rodrig
# ✅ [99] Guardat: Sistema Operatiu client - Ivan Rodriguez Jimenez
# ✅ [100] Guardat: Accés remot - Ivan Rodriguez Jimenez
# ✅ [101] Guardat: Configuració d'entorn d'usuari - Ivan Rodriguez Jimenez
# ✅ [102] Guardat: Configuració de privilegis - Ivan Rodriguez Jimenez
# ✅ [103] Guardat: Creació d'usuaris - Ivan Rodriguez Jimenez
# ✅ [104] Guardat: Imatge del SO acabat - Ivan Rodriguez Jimenez
# ✅ [105] Guardat: Instal·lació de Linux Mint (MATE) - Ivan Rodriguez Jimenez
# ✅ [106] Guardat: Instal·lació i configuració de software necessari - Ivan Rod
# ✅ [107] Guardat: Sistema Operatiu servidor - Ivan Rodriguez Jimenez
# ✅ [108] Guardat: Accés remot al SO - Ivan Rodriguez Jimenez
# ✅ [109] Guardat: Configuració de privilegis - Ivan Rodriguez Jimenez
# ✅ [110] Guardat: Creació d'usuaris necessaris - Ivan Rodriguez Jimenez
# ✅ [111] Guardat: Imatge del SO acabat - Ivan Rodriguez Jimenez
# ✅ [112] Guardat: Instal·lació de Debian - Ivan Rodriguez Jimenez
# ✅ [113] Guardat: Instal·lació i configuració de software necessari - Ivan Rod
# ✅ [114] Guardat: Sostenibilitat - Ivan Rodriguez Jimenez
# ✅ [115] Guardat: Comparativa de consum energètic amb altres dispositius HW -
# ✅ [116] Guardat: Comparativa de l'estàlvi en recursos materials d'una prova e
# ✅ [117] Guardat: Comparativa del cost econòmic de l'aula digital amb material
# ✅ [118] Guardat: Comparativa del temps de preparació i correcció d'una prova
# ✅ [119] Guardat: Optimització del consum energètic de les màquines - Ivan Rod
# ✅ [120] Guardat: Pressupostos d'un sistema energètic sostenible per a l'aula
# ✅ [121] Guardat: Reflexió de l'impacte mediambiental del mal ús de la IA - Iv
# ✅ [122] Guardat: Xarxa de connexió - Ivan Rodriguez Jimenez
# ✅ [123] Guardat: Configuració del punt d'accés - Ivan Rodriguez Jimenez
# ✅ [124] Guardat: Configuració dels clients - Ivan Rodriguez Jimenez
# ✅ [125] Guardat: Filtratge MAC dels dispositius - Ivan Rodriguez Jimenez
# ✅ [126] Guardat: Inventari i etiquetat dels dispositius - Ivan Rodriguez Jime
# ✅ [127] Guardat: Pla d'adreçament de la xarxa - Ivan Rodriguez Jimenez
# ✅ [128] Guardat: Equips de joc - Ivan Rodriguez Jimenez
# ✅ [129] Guardat: Actualitzar BIOS i firmwares quan calgui - Ivan Rodriguez Ji
# ✅ [130] Guardat: Comprovar l’estat físic dels equips i verificar compatibilit
# ✅ [131] Guardat: Detectar i solucionar incidències bàsiques de maquinari - Iv
# ✅ [132] Guardat: Netejar i fer manteniment preventiu dels ordinadors i perifè
# ✅ [133] Guardat: Generació d’un xatbot - Ivan Rodriguez Jimenez
# ✅ [134] Guardat: Crear un document de FAQs habituals en una LAN Party - Ivan
# ✅ [135] Guardat: Integrar el xatbot dins del portal web de la LAN Party - Iva
# ✅ [136] Guardat: Preparació de l'entorn de treball: GitHub, Colab, Google AI
# ✅ [137] Guardat: Preparació de l’entorn de treball: GitHub, Colab, Google AI
# ✅ [138] Guardat: Programació de les funcionalitats bàsiques en el BackEnd i F
# ✅ [139] Guardat: Ús de la IA en la programació i comentaris al codi. Document
# ✅ [140] Guardat: HelpDesk - Ivan Rodriguez Jimenez
# ✅ [141] Guardat: Crear senyalització i instruccions bàsiques - Ivan Rodriguez
# ✅ [142] Guardat: Donar assistència telefònica a incidències internacionals -
# ✅ [143] Guardat: Generar flowcharts per a la resolució d'incidències i consul
# ✅ [144] Guardat: Generar un formulari de sol·licitud d'assistència des del po
# ✅ [145] Guardat: Preparar un manual d'actuació en cas d'emergència - Ivan Rod
# ✅ [146] Guardat: Redactar el pla d'emergència i evacuació de l'espai de la LA
# ✅ [147] Guardat: Imatge pels equips - Ivan Rodriguez Jimenez
# ✅ [148] Guardat: Crear imatge de la màquina template i clonar-la en la resta
# ✅ [149] Guardat: Crear usuaris amb els privilegis necessaris - Ivan Rodriguez
# ✅ [150] Guardat: Instal·lar Windows i Linux en la màquina template - Ivan Rod
# ✅ [151] Guardat: Inventari i etiquetatge de material - Ivan Rodriguez Jimenez
# ✅ [152] Guardat: Intranet de la LAN Party - Ivan Rodriguez Jimenez
# ✅ [153] Guardat: Definir les claus primàries per vincular tasques - Ivan Rodr
# ✅ [154] Guardat: Depuració del codi de Pythom - Ivan Rodriguez Jimenez
# ✅ [155] Guardat: Dissenyar les taules que ha de contenir la BBDD - Ivan Rodri
# ✅ [156] Guardat: Estil corporatiu (css) - Ivan Rodriguez Jimenez
# ✅ [157] Guardat: Generar consultes per extreure informació de la BBDD - Ivan
# ✅ [158] Guardat: Generar formularis d'entrada de dades a la BBDD - Ivan Rodri
# ✅ [159] Guardat: LAN Party EcoTech - Ivan Rodriguez Jimenez
# ✅ [160] Guardat: Analitzar el cicle de vida dels residus generats - Ivan Rodr
# ✅ [161] Guardat: Analitzar la millora que suposa el registre digital dels par
# ✅ [162] Guardat: Definir accions de reducció de residus i consum - Ivan Rodri
# ✅ [163] Guardat: Fer una proposta d'economia circular aplicada - Ivan Rodrigu
# ✅ [164] Guardat: Identificar impactes ambientals de l'esdeveniment - Ivan Rod
# ✅ [165] Guardat: Proposar mesures per reduir l'impacte ambiental de l'esdeven
# ✅ [166] Guardat: Realitzar propostes de millora per transformar la LAN Party
# ✅ [167] Guardat: Material gràfic i de comunicació - Ivan Rodriguez Jimenez
# ✅ [168] Guardat: Crear un petit tour virtual per veure la LAN Party - Ivan Ro
# ✅ [169] Guardat: Crear una presentació multimèdia per fer difusió de l'esdeve
# ✅ [170] Guardat: Dissenyar la cartelleria publicitària de l'esdeveniment - Iv
# ✅ [171] Guardat: Generar i retocar imatges per la cartelleria publicitària -
# ✅ [172] Guardat: Time-lapse amb el making off - Ivan Rodriguez Jimenez
# ✅ [173] Guardat: Web de la LAN Party - Ivan Rodriguez Jimenez
# ✅ [174] Guardat: Crear documentació oficial de l'esdeveniment - Ivan Rodrigue
# ✅ [175] Guardat: Dissenyar el logo de la LAN Party, per fer adhesius pels ass
# ✅ [176] Guardat: Formulari de registre - Ivan Rodriguez Jimenez
# ✅ [177] Guardat: Gravar un videomissatge donant la benvinguda als participant
# ✅ [178] Guardat: Reescriure la normativa de l'esdeveniment en llengua anglesa
# ✅ [179] Guardat: Sites informatiu de la LAN Party - Ivan Rodriguez Jimenez
# ✅ [180] Guardat: Xarxa troncal de la LAN Party - Ivan Rodriguez Jimenez
# ✅ [181] Guardat: Configurar i posar en marxa els switchos principals - Ivan R
# ✅ [182] Guardat: Configurar VLANs per segmentar jugadors, personal i serveis
# ✅ [183] Guardat: Crear informe complet d’incidències i millores - Ivan Rodrig
# ✅ [184] Guardat: Dissenyar el mapa físic i lògic de la xarxa - Ivan Rodriguez
# ✅ [185] Guardat: Generar un pressupost detallat de tot el material necessari
# ✅ [186] Guardat: Implementar QoS per gestionar tràfic de jocs i streaming - I
# ✅ [187] Guardat: Realitzar el cablejat estructurat i etiquetar-lo correctamen
# ✅ [188] Guardat: Verificar el funcionament i resoldre incidències de connecti
# ✅ [189] Guardat: Xarxa Wi-Fi per assistents - Ivan Rodriguez Jimenez
# ✅ [190] Guardat: Adaptació Portafolis - Ivan Rodriguez Jimenez
# ✅ [191] Guardat: Activació de plugins per millorar l’experiència d’usuari - I
# ✅ [192] Guardat: Assegurar el disseny responsive per a tots els dispositius -
# ✅ [193] Guardat: Categoritzar totes les entrades per Mòdul - Ivan Rodriguez J
# ✅ [194] Guardat: Categoritzar totes les entrades per Repte - Ivan Rodriguez J
# ✅ [195] Guardat: Configurar els enllaços externs per a que s’obrin en una fin
# ✅ [196] Guardat: Creació d’enllaços entre pàgines que tinguin relació dins de
# ✅ [197] Guardat: Creació del menú del lloc web - Ivan Rodriguez Jimenez
# ✅ [198] Guardat: Crear una pàgina amb tots els mòduls de 1r curs i fer un enl
# ✅ [199] Guardat: Revisar l’ortografia de tot el lloc web - Ivan Rodriguez Jim
# ✅ [200] Guardat: El Xatbot - Ivan Rodriguez Jimenez
# ✅ [201] Guardat: Comunicació FrontEnd i BackEnd i integració del Widget a la
# ✅ [202] Guardat: Implementació d'un XatBot amb eines de Vivecoding - Ivan Rod
# ✅ [203] Guardat: Integració amb millores funcionals i estètiques del FrontEnd
# ✅ [204] Guardat: Preparació de l'entorn de treball - Ivan Rodriguez Jimenez
# ✅ [205] Guardat: Programació del WebScraping - Ivan Rodriguez Jimenez
# ✅ [206] Guardat: Hackató EcoTech - Ivan Rodriguez Jimenez
# ✅ [207] Guardat: Analitzar el repte de sostenibilitat plantejat per les empre
# ✅ [208] Guardat: Crear l’informe final de resultats i impacte de la Hackató -
# ✅ [209] Guardat: Crear materials visuals sobre sostenibilitat i economia circ
# ✅ [210] Guardat: Crear un sistema d’avaluació infantil per al jurat - Ivan Ro
# ✅ [211] Guardat: Dinamitzar la Hackató aplicant criteris de sostenibilitat -
# ✅ [212] Guardat: Dissenyar el guió complet de la Hackató EcoTech - Ivan Rodri
# ✅ [213] Guardat: Proposar un EcoTech Lab Escolar per donar continuïtat - Ivan
# ✅ [214] Guardat: Internacionalització - Ivan Rodriguez Jimenez
# ✅ [215] Guardat: Active participation in English during the event - Ivan Rodr
# ✅ [216] Guardat: Active participation in English during the event (role inter
# ✅ [217] Guardat: Comprehension of spoken interactions in English - Ivan Rodri
# ✅ [218] Guardat: Creation of a cover letter in English - Ivan Rodriguez Jimen
# ✅ [219] Guardat: Creation of an elevator pitch in English - Ivan Rodriguez Ji
# ✅ [220] Guardat: Cretion of a CV in English - Ivan Rodriguez Jimenez
# ✅ [221] Guardat: IPOP - Ivan Rodriguez Jimenez
# ✅ [222] Guardat: Àmbits de conneixement - Ivan Rodriguez Jimenez
# ✅ [223] Guardat: Autoanàlisi - Ivan Rodriguez Jimenez
# ✅ [224] Guardat: Contractes de treball - Ivan Rodriguez Jimenez
# ✅ [225] Guardat: CV - Ivan Rodriguez Jimenez
# ✅ [226] Guardat: Elevator Pitch - Ivan Rodriguez Jimenez
# ✅ [227] Guardat: Informe iPOP final - Ivan Rodriguez Jimenez
# ✅ [228] Guardat: L'entrevista - Ivan Rodriguez Jimenez
# ✅ [229] Guardat: Mercat Laboral - Ivan Rodriguez Jimenez
# ✅ [230] Guardat: Perfils Professionals - Ivan Rodriguez Jimenez
# ✅ [231] Guardat: Presentació pública de l'iPOP final - Ivan Rodriguez Jimenez
# ✅ [232] Guardat: L'Ecocarpa - Ivan Rodriguez Jimenez
# ✅ [233] Guardat: Configuració de tauletes per respondre el quiz - Ivan Rodrig
# ✅ [234] Guardat: Creació d'un punt de recollida de dispositius electrònics en
# ✅ [235] Guardat: Creació d'un Quiz de l’impacte ambiental de la informàtica -
# ✅ [236] Guardat: Presentació de solucions software sostenibles - Ivan Rodrigu
# ✅ [237] Guardat: La Fira - Ivan Rodriguez Jimenez
# ✅ [238] Guardat: Cartelleria de les carpes - Ivan Rodriguez Jimenez
# ✅ [239] Guardat: Configuració d'un punt d'accés per donar cobertura Wi-Fi als
# ✅ [240] Guardat: Configuració d'un switch amb VLANs per connectar els disposi
# ✅ [241] Guardat: Configuració de tauletes per fer el registre in-situ - Ivan
# ✅ [242] Guardat: Desplegament en MV d'un backup del WP personal - Ivan Rodrig
# ✅ [243] Guardat: Fulletó informatiu del cicle - Ivan Rodriguez Jimenez
# ✅ [244] Guardat: Generació de vCard amb QR pels assistents a l'esdeveniment -
# ✅ [245] Guardat: Reciclatge de cablejat de xarxa per fer les connexions dels
# ✅ [246] Guardat: Tour Virtual - Ivan Rodriguez Jimenez
# ✅ [247] Guardat: Afegir al tour elements multimèdia, vídeos, imatges… - Ivan
# ✅ [248] Guardat: Afegir al tour punts d'informació. "hotspots". - Ivan Rodrig
# ✅ [249] Guardat: Crear el tour virtual amb les imatges preses. - Ivan Rodrigu
# ✅ [250] Guardat: Fer comparativa de diverses aplicacions gratuïtes i online p
# ✅ [251] Guardat: Fer les fotografies panoràmiques per fer un tour virtual 3D
# ✅ [252] Guardat: Incrustar el tour en el vostre wordpress. - Ivan Rodriguez J
# ✅ [253] Guardat: Repte 1.5 - Ivan Rodriguez Jimenez
# ✅ [254] Guardat: Constitució de l'agència - Ivan Rodriguez Jimenez
# ✅ [255] Guardat: Àmbits de coneixement - Ivan Rodriguez Jimenez
# ✅ [256] Guardat: Contractes de treball de l'agència - Ivan Rodriguez Jimenez
# ✅ [257] Guardat: Gravació entrevista de treball - Ivan Rodriguez Jimenez
#
# 📁 BBDD FINALITZADA: 257 pàgines i entrades guardades amb èxit!
#
# 🌍 URL PER AL TEU JAVASCRIPT:
# https://overponderous-kandace-insuperably.ngrok-free.dev/ask
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
